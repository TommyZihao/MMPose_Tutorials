# %% [markdown]
# # 三角板关键点检测-下载config配置文件
#
# 同济子豪兄 2023-4-6

# %% [markdown]
# ## 进入 mmpose 主目录

# %%
import os
os.chdir('mmpose')

# %% [markdown]
# ## 下载config配置文件至`data`目录

# %%
# !rm -rf data/rtmpose-s_triangle_8xb256-420e_coco-256x192.py
# !wget https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220610-mmpose/triangle_dataset/rtmpose-s_triangle_8xb256-420e_coco-256x192.py -P data
# Out:
# --2023-05-18 10:53:07--  https://zihao-openmmlab.obs.cn-east-3.myhuaweicloud.com/20220610-mmpose/triangle_dataset/rtmpose-s_triangle_8xb256-420e_coco-256x192.py
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 13061 (13K) [binary/octet-stream]
# 正在保存至: “data/rtmpose-s_triangle_8xb256-420e_coco-256x192.py”
#
# rtmpose-s_triangle_ 100%[===================>]  12.75K  --.-KB/s    用时 0.01s
#
# 2023-05-18 10:53:07 (1.05 MB/s) - 已保存 “data/rtmpose-s_triangle_8xb256-420e_coco-256x192.py” [13061/13061])
