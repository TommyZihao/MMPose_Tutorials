# %% [markdown]
# # 三角板目标检测-训练
#
# 同济子豪兄 2023-4-3

# %% [markdown]
# ## 进入mmdetection主目录

# %%
import os
os.chdir('mmdetection')

# %% [markdown]
# ## 目标检测算法：Faster R CNN

# %% [markdown]
# ### 下载config配置文件

# %%
# !rm -rf data/faster_r_cnn_triangle.py
# !wget https://zihao-openmmlab.obs.myhuaweicloud.com/20220610-mmpose/triangle_dataset/faster_r_cnn_triangle.py -P data
# Out:
# --2023-04-04 17:48:17--  https://zihao-openmmlab.obs.myhuaweicloud.com/20220610-mmpose/triangle_dataset/faster_r_cnn_triangle.py
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 7587 (7.4K) [binary/octet-stream]
# 正在保存至: “data/faster_r_cnn_triangle.py”
#
# faster_r_cnn_triang 100%[===================>]   7.41K  --.-KB/s    用时 0.006s
#
# 2023-04-04 17:48:17 (1.21 MB/s) - 已保存 “data/faster_r_cnn_triangle.py” [7587/7587])

# %% [markdown]
# ### 训练

# %%
# !python tools/train.py data/faster_r_cnn_triangle.py

# %% [markdown]
# ## 目标检测算法：RTMDet

# %% [markdown]
# ### 下载config配置文件

# %%
# !rm -rf data/rtmdet_tiny_triangle.py
# !wget https://zihao-openmmlab.obs.myhuaweicloud.com/20220610-mmpose/triangle_dataset/rtmdet_tiny_triangle.py -P data
# Out:
# --2023-04-04 17:48:21--  https://zihao-openmmlab.obs.myhuaweicloud.com/20220610-mmpose/triangle_dataset/rtmdet_tiny_triangle.py
# 正在连接 172.16.0.13:5848... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度： 8694 (8.5K) [binary/octet-stream]
# 正在保存至: “data/rtmdet_tiny_triangle.py”
#
# rtmdet_tiny_triangl 100%[===================>]   8.49K  --.-KB/s    用时 0.01s
#
# 2023-04-04 17:48:22 (885 KB/s) - 已保存 “data/rtmdet_tiny_triangle.py” [8694/8694])

# %% [markdown]
# ### 训练

# %%
# !python tools/train.py data/rtmdet_tiny_triangle.py
# Out:
# 04/04 17:48:25 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.7.10 (default, Jun  4 2021, 14:48:32) [GCC 7.5.0]
#     CUDA available: True
#     numpy_random_seed: 1459478410
#     GPU 0: NVIDIA GeForce RTX 3080
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.2, V11.2.152
#     GCC: gcc (Ubuntu 9.3.0-17ubuntu1~20.04) 9.3.0
#     PyTorch: 1.10.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.3
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.2
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.3, CUDNN_VERSION=8.2.0, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON,
#
#     TorchVision: 0.11.2+cu113
#     OpenCV: 4.5.4
#     MMEngine: 0.7.0
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: None
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 04/04 17:48:27 - mmengine - INFO - Config:
# dataset_type = 'CocoDataset'
# data_root = 'data/Triangle_140_Keypoint_Dataset/'
# metainfo = dict(classes=('sjb_rect', ))
# NUM_CLASSES = 1
# MAX_EPOCHS = 200
# TRAIN_BATCH_SIZE = 4
# VAL_BATCH_SIZE = 2
# stage2_num_epochs = 20
# base_lr = 0.004
# VAL_INTERVAL = 5
# default_scope = 'mmdet'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=1),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(
#         type='CheckpointHook',
#         interval=10,
#         max_keep_ckpts=2,
#         save_best='coco/bbox_mAP'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='DetVisualizationHook'))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='DetLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(type='LogProcessor', window_size=50, by_epoch=True)
# log_level = 'INFO'
# load_from = None
# resume = False
# train_cfg = dict(
#     type='EpochBasedTrainLoop',
#     max_epochs=200,
#     val_interval=5,
#     dynamic_intervals=[(180, 1)])
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=1e-05, by_epoch=False, begin=0,
#         end=1000),
#     dict(
#         type='CosineAnnealingLR',
#         eta_min=0.0002,
#         begin=150,
#         end=300,
#         T_max=150,
#         by_epoch=True,
#         convert_to_iter_based=True)
# ]
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='AdamW', lr=0.004, weight_decay=0.05),
#     paramwise_cfg=dict(
#         norm_decay_mult=0, bias_decay_mult=0, bypass_duplicate=True))
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# backend_args = None
# train_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         type='CachedMosaic',
#         img_scale=(640, 640),
#         pad_val=114.0,
#         max_cached_images=20,
#         random_pop=False),
#     dict(
#         type='RandomResize',
#         scale=(1280, 1280),
#         ratio_range=(0.5, 2.0),
#         keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(640, 640)),
#     dict(type='YOLOXHSVRandomAug'),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='Pad', size=(640, 640), pad_val=dict(img=(114, 114, 114))),
#     dict(
#         type='CachedMixUp',
#         img_scale=(640, 640),
#         ratio_range=(1.0, 1.0),
#         max_cached_images=10,
#         random_pop=False,
#         pad_val=(114, 114, 114),
#         prob=0.5),
#     dict(type='PackDetInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='Resize', scale=(640, 640), keep_ratio=True),
#     dict(type='Pad', size=(640, 640), pad_val=dict(img=(114, 114, 114))),
#     dict(
#         type='PackDetInputs',
#         meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                    'scale_factor'))
# ]
# train_dataloader = dict(
#     batch_size=4,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True),
#     batch_sampler=None,
#     dataset=dict(
#         type='CocoDataset',
#         data_root='data/Triangle_140_Keypoint_Dataset/',
#         metainfo=dict(classes=('sjb_rect', )),
#         ann_file='train_coco.json',
#         data_prefix=dict(img='images/'),
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='CachedMosaic',
#                 img_scale=(640, 640),
#                 pad_val=114.0,
#                 max_cached_images=20,
#                 random_pop=False),
#             dict(
#                 type='RandomResize',
#                 scale=(1280, 1280),
#                 ratio_range=(0.5, 2.0),
#                 keep_ratio=True),
#             dict(type='RandomCrop', crop_size=(640, 640)),
#             dict(type='YOLOXHSVRandomAug'),
#             dict(type='RandomFlip', prob=0.5),
#             dict(
#                 type='Pad', size=(640, 640),
#                 pad_val=dict(img=(114, 114, 114))),
#             dict(
#                 type='CachedMixUp',
#                 img_scale=(640, 640),
#                 ratio_range=(1.0, 1.0),
#                 max_cached_images=10,
#                 random_pop=False,
#                 pad_val=(114, 114, 114),
#                 prob=0.5),
#             dict(type='PackDetInputs')
#         ],
#         backend_args=None),
#     pin_memory=True)
# val_dataloader = dict(
#     batch_size=2,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='data/Triangle_140_Keypoint_Dataset/',
#         metainfo=dict(classes=('sjb_rect', )),
#         ann_file='val_coco.json',
#         data_prefix=dict(img='images/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(640, 640), keep_ratio=True),
#             dict(
#                 type='Pad', size=(640, 640),
#                 pad_val=dict(img=(114, 114, 114))),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ],
#         backend_args=None))
# test_dataloader = dict(
#     batch_size=2,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='data/Triangle_140_Keypoint_Dataset/',
#         metainfo=dict(classes=('sjb_rect', )),
#         ann_file='val_coco.json',
#         data_prefix=dict(img='images/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(640, 640), keep_ratio=True),
#             dict(
#                 type='Pad', size=(640, 640),
#                 pad_val=dict(img=(114, 114, 114))),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ],
#         backend_args=None))
# val_evaluator = dict(
#     type='CocoMetric',
#     ann_file='data/Triangle_140_Keypoint_Dataset/val_coco.json',
#     metric=['bbox'],
#     format_only=False,
#     backend_args=None,
#     proposal_nums=(100, 1, 10))
# test_evaluator = dict(
#     type='CocoMetric',
#     ann_file='data/Triangle_140_Keypoint_Dataset/val_coco.json',
#     metric=['bbox'],
#     format_only=False,
#     backend_args=None,
#     proposal_nums=(100, 1, 10))
# tta_model = dict(
#     type='DetTTAModel',
#     tta_cfg=dict(nms=dict(type='nms', iou_threshold=0.6), max_per_img=100))
# tta_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(
#         type='TestTimeAug',
#         transforms=[[{
#             'type': 'Resize',
#             'scale': (640, 640),
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale': (320, 320),
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale': (960, 960),
#             'keep_ratio': True
#         }],
#                     [{
#                         'type': 'RandomFlip',
#                         'prob': 1.0
#                     }, {
#                         'type': 'RandomFlip',
#                         'prob': 0.0
#                     }],
#                     [{
#                         'type': 'Pad',
#                         'size': (960, 960),
#                         'pad_val': {
#                             'img': (114, 114, 114)
#                         }
#                     }],
#                     [{
#                         'type':
#                         'PackDetInputs',
#                         'meta_keys':
#                         ('img_id', 'img_path', 'ori_shape', 'img_shape',
#                          'scale_factor', 'flip', 'flip_direction')
#                     }]])
# ]
# model = dict(
#     type='RTMDet',
#     data_preprocessor=dict(
#         type='DetDataPreprocessor',
#         mean=[103.53, 116.28, 123.675],
#         std=[57.375, 57.12, 58.395],
#         bgr_to_rgb=False,
#         batch_augments=None),
#     backbone=dict(
#         type='CSPNeXt',
#         arch='P5',
#         expand_ratio=0.5,
#         deepen_factor=0.167,
#         widen_factor=0.375,
#         channel_attention=True,
#         norm_cfg=dict(type='SyncBN'),
#         act_cfg=dict(type='SiLU', inplace=True),
#         init_cfg=dict(
#             type='Pretrained',
#             prefix='backbone.',
#             checkpoint=
#             'https://download.openmmlab.com/mmdetection/v3.0/rtmdet/cspnext_rsb_pretrain/cspnext-tiny_imagenet_600e.pth'
#         )),
#     neck=dict(
#         type='CSPNeXtPAFPN',
#         in_channels=[96, 192, 384],
#         out_channels=96,
#         num_csp_blocks=1,
#         expand_ratio=0.5,
#         norm_cfg=dict(type='SyncBN'),
#         act_cfg=dict(type='SiLU', inplace=True)),
#     bbox_head=dict(
#         type='RTMDetSepBNHead',
#         num_classes=1,
#         in_channels=96,
#         stacked_convs=2,
#         feat_channels=96,
#         anchor_generator=dict(
#             type='MlvlPointGenerator', offset=0, strides=[8, 16, 32]),
#         bbox_coder=dict(type='DistancePointBBoxCoder'),
#         loss_cls=dict(
#             type='QualityFocalLoss',
#             use_sigmoid=True,
#             beta=2.0,
#             loss_weight=1.0),
#         loss_bbox=dict(type='GIoULoss', loss_weight=2.0),
#         with_objectness=False,
#         exp_on_reg=False,
#         share_conv=True,
#         pred_kernel_size=1,
#         norm_cfg=dict(type='SyncBN'),
#         act_cfg=dict(type='SiLU', inplace=True)),
#     train_cfg=dict(
#         assigner=dict(type='DynamicSoftLabelAssigner', topk=13),
#         allowed_border=-1,
#         pos_weight=-1,
#         debug=False),
#     test_cfg=dict(
#         nms_pre=30000,
#         min_bbox_size=0,
#         score_thr=0.001,
#         nms=dict(type='nms', iou_threshold=0.65),
#         max_per_img=300))
# train_pipeline_stage2 = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         type='RandomResize',
#         scale=(640, 640),
#         ratio_range=(0.5, 2.0),
#         keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(640, 640)),
#     dict(type='YOLOXHSVRandomAug'),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='Pad', size=(640, 640), pad_val=dict(img=(114, 114, 114))),
#     dict(type='PackDetInputs')
# ]
# custom_hooks = [
#     dict(
#         type='EMAHook',
#         ema_type='ExpMomentumEMA',
#         momentum=0.0002,
#         update_buffers=True,
#         priority=49),
#     dict(
#         type='PipelineSwitchHook',
#         switch_epoch=180,
#         switch_pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='RandomResize',
#                 scale=(640, 640),
#                 ratio_range=(0.5, 2.0),
#                 keep_ratio=True),
#             dict(type='RandomCrop', crop_size=(640, 640)),
#             dict(type='YOLOXHSVRandomAug'),
#             dict(type='RandomFlip', prob=0.5),
#             dict(
#                 type='Pad', size=(640, 640),
#                 pad_val=dict(img=(114, 114, 114))),
#             dict(type='PackDetInputs')
#         ])
# ]
# launcher = 'none'
# work_dir = './work_dirs/rtmdet_tiny_triangle'
#
# 04/04 17:48:37 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 04/04 17:48:37 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_load_checkpoint:
# (49          ) EMAHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
# (NORMAL      ) PipelineSwitchHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_save_checkpoint:
# (49          ) EMAHook
#  --------------------
# before_test_epoch:
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stem.0.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stem.0.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stem.1.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stem.1.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stem.2.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stem.2.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage1.0.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage1.0.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage1.1.main_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage1.1.main_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage1.1.short_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage1.1.short_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage1.1.final_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage1.1.final_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv1.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv1.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage1.1.attention.fc.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage2.0.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage2.0.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage2.1.main_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage2.1.main_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage2.1.short_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage2.1.short_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage2.1.final_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage2.1.final_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv1.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv1.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage2.1.attention.fc.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage3.0.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage3.0.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage3.1.main_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage3.1.main_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage3.1.short_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage3.1.short_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage3.1.final_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage3.1.final_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv1.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv1.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage3.1.attention.fc.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage4.0.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage4.0.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage4.1.conv1.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage4.1.conv1.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage4.1.conv2.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage4.1.conv2.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage4.2.main_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage4.2.main_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage4.2.short_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage4.2.short_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage4.2.final_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage4.2.final_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv1.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv1.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- backbone.stage4.2.attention.fc.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.reduce_layers.0.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.reduce_layers.0.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.reduce_layers.1.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.reduce_layers.1.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.main_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.main_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.short_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.short_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.final_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.final_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.0.conv1.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.0.conv1.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.main_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.main_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.short_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.short_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.final_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.final_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.0.conv1.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.0.conv1.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.downsamples.0.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.downsamples.0.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.downsamples.1.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.downsamples.1.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.main_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.main_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.short_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.short_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.final_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.final_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.0.conv1.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.0.conv1.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.main_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.main_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.short_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.short_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.final_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.final_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.0.conv1.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.0.conv1.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.out_convs.0.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.out_convs.0.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.out_convs.1.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.out_convs.1.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.out_convs.2.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- neck.out_convs.2.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.0.0.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.0.0.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.0.1.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.0.1.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - WARNING - bbox_head.cls_convs.1.0.conv is duplicate. It is skipped since bypass_duplicate=True
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.1.0.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.1.0.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - WARNING - bbox_head.cls_convs.1.1.conv is duplicate. It is skipped since bypass_duplicate=True
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.1.1.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.1.1.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - WARNING - bbox_head.cls_convs.2.0.conv is duplicate. It is skipped since bypass_duplicate=True
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.2.0.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.2.0.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - WARNING - bbox_head.cls_convs.2.1.conv is duplicate. It is skipped since bypass_duplicate=True
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.2.1.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.2.1.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.0.0.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.0.0.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.0.1.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.0.1.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - WARNING - bbox_head.reg_convs.1.0.conv is duplicate. It is skipped since bypass_duplicate=True
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.1.0.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.1.0.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - WARNING - bbox_head.reg_convs.1.1.conv is duplicate. It is skipped since bypass_duplicate=True
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.1.1.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.1.1.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - WARNING - bbox_head.reg_convs.2.0.conv is duplicate. It is skipped since bypass_duplicate=True
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.2.0.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.2.0.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - WARNING - bbox_head.reg_convs.2.1.conv is duplicate. It is skipped since bypass_duplicate=True
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.2.1.bn.weight:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.2.1.bn.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.rtm_cls.0.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.rtm_cls.1.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.rtm_cls.2.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.rtm_reg.0.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.rtm_reg.1.bias:weight_decay=0.0
# 04/04 17:48:39 - mmengine - INFO - paramwise_options -- bbox_head.rtm_reg.2.bias:weight_decay=0.0
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 04/04 17:48:41 - mmengine - INFO - load backbone. in model from: https://download.openmmlab.com/mmdetection/v3.0/rtmdet/cspnext_rsb_pretrain/cspnext-tiny_imagenet_600e.pth
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmdetection/v3.0/rtmdet/cspnext_rsb_pretrain/cspnext-tiny_imagenet_600e.pth
# 04/04 17:48:41 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 04/04 17:48:41 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 04/04 17:48:41 - mmengine - INFO - Checkpoints will be saved to /home/featurize/work/关键点检测/mmdetection/work_dirs/rtmdet_tiny_triangle.
# /environment/miniconda3/lib/python3.7/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 04/04 17:48:43 - mmengine - INFO - Epoch(train)   [1][ 1/28]  lr: 4.0000e-08  eta: 2:58:14  time: 1.9100  data_time: 1.5784  memory: 1280  loss: 0.0453  loss_cls: 0.0337  loss_bbox: 0.0116
# 04/04 17:48:43 - mmengine - INFO - Epoch(train)   [1][ 2/28]  lr: 4.0440e-06  eta: 1:36:46  time: 1.0372  data_time: 0.7930  memory: 1337  loss: 0.0423  loss_cls: 0.0337  loss_bbox: 0.0086
# 04/04 17:48:43 - mmengine - INFO - Epoch(train)   [1][ 3/28]  lr: 8.0479e-06  eta: 1:09:09  time: 0.7414  data_time: 0.5307  memory: 1337  loss: 0.0402  loss_cls: 0.0337  loss_bbox: 0.0065
# 04/04 17:48:44 - mmengine - INFO - Epoch(train)   [1][ 4/28]  lr: 1.2052e-05  eta: 0:54:52  time: 0.5884  data_time: 0.3990  memory: 1338  loss: 0.0403  loss_cls: 0.0337  loss_bbox: 0.0066
# 04/04 17:48:45 - mmengine - INFO - Epoch(train)   [1][ 5/28]  lr: 1.6056e-05  eta: 1:19:22  time: 0.8512  data_time: 0.6692  memory: 1340  loss: 0.0455  loss_cls: 0.0336  loss_bbox: 0.0118
# 04/04 17:48:46 - mmengine - INFO - Epoch(train)   [1][ 6/28]  lr: 2.0060e-05  eta: 1:08:47  time: 0.7378  data_time: 0.5586  memory: 1338  loss: 0.0473  loss_cls: 0.0336  loss_bbox: 0.0137
# 04/04 17:48:47 - mmengine - INFO - Epoch(train)   [1][ 7/28]  lr: 2.4064e-05  eta: 1:16:42  time: 0.8229  data_time: 0.6466  memory: 1337  loss: 0.0495  loss_cls: 0.0336  loss_bbox: 0.0159
# 04/04 17:48:47 - mmengine - INFO - Epoch(train)   [1][ 8/28]  lr: 2.8068e-05  eta: 1:09:04  time: 0.7412  data_time: 0.5665  memory: 1337  loss: 0.0523  loss_cls: 0.0335  loss_bbox: 0.0188
# 04/04 17:48:49 - mmengine - INFO - Epoch(train)   [1][ 9/28]  lr: 3.2072e-05  eta: 1:17:03  time: 0.8269  data_time: 0.6536  memory: 1338  loss: 0.0534  loss_cls: 0.0335  loss_bbox: 0.0199
# 04/04 18:03:53 - mmengine - INFO - Epoch(train)  [46][14/28]  lr: 4.0000e-03  eta: 0:48:23  time: 0.7240  data_time: 0.5793  memory: 1340  loss: 0.8214  loss_cls: 0.3536  loss_bbox: 0.4678
# 04/04 18:03:54 - mmengine - INFO - Epoch(train)  [46][15/28]  lr: 4.0000e-03  eta: 0:48:20  time: 0.6810  data_time: 0.5367  memory: 1337  loss: 0.8215  loss_cls: 0.3545  loss_bbox: 0.4670
# 04/04 18:03:54 - mmengine - INFO - Epoch(train)  [46][16/28]  lr: 4.0000e-03  eta: 0:48:19  time: 0.6889  data_time: 0.5449  memory: 1337  loss: 0.8215  loss_cls: 0.3550  loss_bbox: 0.4666
# 04/04 18:03:56 - mmengine - INFO - Epoch(train)  [46][17/28]  lr: 4.0000e-03  eta: 0:48:24  time: 0.7318  data_time: 0.5881  memory: 1339  loss: 0.8179  loss_cls: 0.3535  loss_bbox: 0.4644
# 04/04 18:03:57 - mmengine - INFO - Epoch(train)  [46][18/28]  lr: 4.0000e-03  eta: 0:48:22  time: 0.7318  data_time: 0.5880  memory: 1338  loss: 0.8154  loss_cls: 0.3531  loss_bbox: 0.4623
# 04/04 18:03:57 - mmengine - INFO - Epoch(train)  [46][19/28]  lr: 4.0000e-03  eta: 0:48:19  time: 0.6931  data_time: 0.5493  memory: 1340  loss: 0.8123  loss_cls: 0.3530  loss_bbox: 0.4594
# 04/04 18:03:57 - mmengine - INFO - Epoch(train)  [46][20/28]  lr: 4.0000e-03  eta: 0:48:17  time: 0.6929  data_time: 0.5493  memory: 1337  loss: 0.8121  loss_cls: 0.3540  loss_bbox: 0.4581
# 04/04 18:03:59 - mmengine - INFO - Epoch(train)  [46][21/28]  lr: 4.0000e-03  eta: 0:48:21  time: 0.7258  data_time: 0.5823  memory: 1341  loss: 0.8064  loss_cls: 0.3502  loss_bbox: 0.4562
# 04/04 18:03:59 - mmengine - INFO - Epoch(train)  [46][22/28]  lr: 4.0000e-03  eta: 0:48:18  time: 0.7256  data_time: 0.5823  memory: 1340  loss: 0.8036  loss_cls: 0.3475  loss_bbox: 0.4562
# 04/04 18:03:59 - mmengine - INFO - Epoch(train)  [46][23/28]  lr: 4.0000e-03  eta: 0:48:16  time: 0.6772  data_time: 0.5341  memory: 1342  loss: 0.8047  loss_cls: 0.3480  loss_bbox: 0.4567
# 04/04 18:03:59 - mmengine - INFO - Epoch(train)  [46][24/28]  lr: 4.0000e-03  eta: 0:48:13  time: 0.6556  data_time: 0.5127  memory: 1337  loss: 0.8043  loss_cls: 0.3493  loss_bbox: 0.4550
# 04/04 18:04:01 - mmengine - INFO - Epoch(train)  [46][25/28]  lr: 4.0000e-03  eta: 0:48:17  time: 0.6920  data_time: 0.5486  memory: 1338  loss: 0.8070  loss_cls: 0.3508  loss_bbox: 0.4561
# 04/04 18:04:01 - mmengine - INFO - Epoch(train)  [46][26/28]  lr: 4.0000e-03  eta: 0:48:14  time: 0.6920  data_time: 0.5486  memory: 1338  loss: 0.8028  loss_cls: 0.3484  loss_bbox: 0.4544
# 04/04 18:04:02 - mmengine - INFO - Epoch(train)  [46][27/28]  lr: 4.0000e-03  eta: 0:48:12  time: 0.6760  data_time: 0.5329  memory: 1342  loss: 0.8037  loss_cls: 0.3480  loss_bbox: 0.4558
# 04/04 18:04:02 - mmengine - INFO - Exp name: rtmdet_tiny_triangle_20230404_174824
# 04/04 18:04:02 - mmengine - INFO - Epoch(train)  [46][28/28]  lr: 4.0000e-03  eta: 0:48:09  time: 0.6418  data_time: 0.4990  memory: 1337  loss: 0.8017  loss_cls: 0.3465  loss_bbox: 0.4551
# 04/04 18:04:04 - mmengine - INFO - Epoch(train)  [47][ 1/28]  lr: 4.0000e-03  eta: 0:48:14  time: 0.6809  data_time: 0.5384  memory: 1342  loss: 0.7998  loss_cls: 0.3435  loss_bbox: 0.4563
# 04/04 18:04:04 - mmengine - INFO - Epoch(train)  [47][ 2/28]  lr: 4.0000e-03  eta: 0:48:12  time: 0.6839  data_time: 0.5417  memory: 1342  loss: 0.7973  loss_cls: 0.3429  loss_bbox: 0.4544
# 04/04 18:04:04 - mmengine - INFO - Epoch(train)  [47][ 3/28]  lr: 4.0000e-03  eta: 0:48:09  time: 0.6812  data_time: 0.5393  memory: 1338  loss: 0.8040  loss_cls: 0.3468  loss_bbox: 0.4572
# 04/04 18:04:04 - mmengine - INFO - Epoch(train)  [47][ 4/28]  lr: 4.0000e-03  eta: 0:48:07  time: 0.6466  data_time: 0.5049  memory: 1338  loss: 0.8034  loss_cls: 0.3472  loss_bbox: 0.4562
# 04/04 18:04:06 - mmengine - INFO - Epoch(train)  [47][ 5/28]  lr: 4.0000e-03  eta: 0:48:10  time: 0.6808  data_time: 0.5390  memory: 1339  loss: 0.8045  loss_cls: 0.3476  loss_bbox: 0.4569
# 04/04 18:04:06 - mmengine - INFO - Epoch(train)  [47][ 6/28]  lr: 4.0000e-03  eta: 0:48:08  time: 0.6814  data_time: 0.5396  memory: 1341  loss: 0.8051  loss_cls: 0.3474  loss_bbox: 0.4577
# 04/04 18:04:07 - mmengine - INFO - Epoch(train)  [47][ 7/28]  lr: 4.0000e-03  eta: 0:48:06  time: 0.6788  data_time: 0.5368  memory: 1344  loss: 0.8095  loss_cls: 0.3494  loss_bbox: 0.4601
# 04/04 18:04:07 - mmengine - INFO - Epoch(train)  [47][ 8/28]  lr: 4.0000e-03  eta: 0:48:03  time: 0.6502  data_time: 0.5085  memory: 1337  loss: 0.8135  loss_cls: 0.3533  loss_bbox: 0.4603
# 04/04 18:04:09 - mmengine - INFO - Epoch(train)  [47][ 9/28]  lr: 4.0000e-03  eta: 0:48:07  time: 0.6862  data_time: 0.5450  memory: 1340  loss: 0.8136  loss_cls: 0.3546  loss_bbox: 0.4590
# 04/04 18:04:09 - mmengine - INFO - Epoch(train)  [47][10/28]  lr: 4.0000e-03  eta: 0:48:04  time: 0.6859  data_time: 0.5450  memory: 1337  loss: 0.8137  loss_cls: 0.3551  loss_bbox: 0.4587
# 04/04 18:04:09 - mmengine - INFO - Epoch(train)  [47][11/28]  lr: 4.0000e-03  eta: 0:48:02  time: 0.6762  data_time: 0.5355  memory: 1339  loss: 0.8129  loss_cls: 0.3550  loss_bbox: 0.4579
# 04/04 18:04:09 - mmengine - INFO - Epoch(train)  [47][12/28]  lr: 4.0000e-03  eta: 0:48:00  time: 0.6502  data_time: 0.5093  memory: 1339  loss: 0.8134  loss_cls: 0.3562  loss_bbox: 0.4572
# 04/04 18:04:11 - mmengine - INFO - Epoch(train)  [47][13/28]  lr: 4.0000e-03  eta: 0:48:03  time: 0.6879  data_time: 0.5467  memory: 1342  loss: 0.8094  loss_cls: 0.3540  loss_bbox: 0.4553
# 04/04 18:04:11 - mmengine - INFO - Epoch(train)  [47][14/28]  lr: 4.0000e-03  eta: 0:48:01  time: 0.6879  data_time: 0.5467  memory: 1340  loss: 0.8095  loss_cls: 0.3536  loss_bbox: 0.4558
# 04/04 18:04:11 - mmengine - INFO - Epoch(train)  [47][15/28]  lr: 4.0000e-03  eta: 0:47:58  time: 0.6732  data_time: 0.5323  memory: 1341  loss: 0.8073  loss_cls: 0.3524  loss_bbox: 0.4549
# 04/04 18:04:12 - mmengine - INFO - Epoch(train)  [47][16/28]  lr: 4.0000e-03  eta: 0:47:56  time: 0.6354  data_time: 0.4942  memory: 1338  loss: 0.8048  loss_cls: 0.3522  loss_bbox: 0.4526
# 04/04 18:04:14 - mmengine - INFO - Epoch(train)  [47][17/28]  lr: 4.0000e-03  eta: 0:48:00  time: 0.6763  data_time: 0.5348  memory: 1342  loss: 0.8047  loss_cls: 0.3513  loss_bbox: 0.4534
# 04/04 18:04:14 - mmengine - INFO - Epoch(train)  [47][18/28]  lr: 4.0000e-03  eta: 0:47:58  time: 0.6766  data_time: 0.5348  memory: 1337  loss: 0.8050  loss_cls: 0.3510  loss_bbox: 0.4540
# 04/04 18:04:14 - mmengine - INFO - Epoch(train)  [47][19/28]  lr: 4.0000e-03  eta: 0:47:56  time: 0.6746  data_time: 0.5324  memory: 1337  loss: 0.8068  loss_cls: 0.3514  loss_bbox: 0.4554
# 04/04 18:04:14 - mmengine - INFO - Epoch(train)  [47][20/28]  lr: 4.0000e-03  eta: 0:47:53  time: 0.6490  data_time: 0.5061  memory: 1341  loss: 0.8066  loss_cls: 0.3503  loss_bbox: 0.4562
# 04/04 18:04:16 - mmengine - INFO - Epoch(train)  [47][21/28]  lr: 4.0000e-03  eta: 0:47:57  time: 0.6877  data_time: 0.5451  memory: 1342  loss: 0.8083  loss_cls: 0.3509  loss_bbox: 0.4573
# 04/04 18:04:17 - mmengine - INFO - Epoch(train)  [47][22/28]  lr: 4.0000e-03  eta: 0:47:55  time: 0.6875  data_time: 0.5451  memory: 1339  loss: 0.8071  loss_cls: 0.3496  loss_bbox: 0.4574
# 04/04 18:04:17 - mmengine - INFO - Epoch(train)  [47][23/28]  lr: 4.0000e-03  eta: 0:47:53  time: 0.6324  data_time: 0.4902  memory: 1337  loss: 0.8138  loss_cls: 0.3536  loss_bbox: 0.4602
# 04/04 18:04:17 - mmengine - INFO - Epoch(train)  [47][24/28]  lr: 4.0000e-03  eta: 0:47:50  time: 0.6325  data_time: 0.4901  memory: 1340  loss: 0.8172  loss_cls: 0.3556  loss_bbox: 0.4616
