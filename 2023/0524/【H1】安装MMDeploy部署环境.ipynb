# %% [markdown]
# # 安装MMDeploy部署环境

# %% [markdown]
# ## 安装MMDeploy

# %%
# !pip install mmdeploy==1.0.0

# %% [markdown]
# ## 安装ONNX Runtime

# %%
# !pip install onnxruntime

# !pip install onnxruntime-gpu

# %% [markdown]
# ## 下载MMDeploy

# %%
# !rm -rf mmdeploy

# %%
# !git clone https://github.com/open-mmlab/mmdeploy.git
# Out:
# 正克隆到 'mmdeploy'...
# remote: Enumerating objects: 23632, done.
# remote: Counting objects: 100% (5814/5814), done.
# remote: Compressing objects: 100% (840/840), done.
# remote: Total 23632 (delta 5137), reused 4996 (delta 4969), pack-reused 17818
# 接收对象中: 100% (23632/23632), 12.06 MiB | 6.38 MiB/s, 完成.
# 处理 delta 中: 100% (15418/15418), 完成.
# 正在更新文件: 100% (1790/1790), 完成.

# %% [markdown]
# ## 验证安装成功

# %%
import mmdeploy
print('MMDeploy 版本', mmdeploy.__version__)
# Out:
# MMDeploy 版本 1.0.0
